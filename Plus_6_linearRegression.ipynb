# %%
import pandas as pd
import numpy as np

# %%
# sklearn에서 캘리포니아 집값 예측 데이터셋 가져오기
from sklearn.datasets import fetch_california_housing

# numpy에서 소수점 넷째자리까지만 출력
np.set_printoptions(precision=4, suppress=True)

data = fetch_california_housing()
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# Cell In[3], line 7
#       4 # numpy에서 소수점 넷째자리까지만 출력
#       5 np.set_printoptions(precision=4, suppress=True)
# ----> 7 data = fetch_california_housing()
#
# File c:\Users\User\miniconda3\envs\DS\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...

# %%
# data의 특성을 확인
# 행의 개수: 20640
# 열의 특성: #numeric

print(data["DESCR"])

# %% [markdown]
# ##### Medinc: 구역 내 가구의 중간 소득(소득의 중앙값)
# ##### HouseAge: 구역 내 주택 연령의 중간값
# ##### AveRooms: 가구당 평균 방 수
# ##### AveBedrms: 가구당 평균 침실 수
# ##### Population: 구역 내 총 인구 수
# ##### AveOccup: 가구당 평균 인원 수
# ##### Latitude: 구역의 위도 <dr>
# ##### Longitude: 구역의 경도 <dr>
