# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 파일의 경로설정
import os 

HOME =  os.getcwd 

trainPath = os.path.join(HOME, 'data', 'train.csv')
testPath = os.path.join(HOME, 'data', 'test.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 import os
#       4 HOME =  os.getcwd
# ----> 6 trainPath = os.path.join(HOME, 'data', 'train.csv')
#       7 testPath = os.path.join(HOME, 'data', 'test.csv')
#
# File <frozen ntpath>:109, in join(path, *paths)
#
# TypeError: expected str, bytes or os.PathLike object, not builtin_function_or_method

# %% [markdown]
# ### 데이터 불러오기

# %%
train_df = pd.read_csv(trainPath)
train_df.head()

# %%
test_df = pd.read_csv(testPath)
test_df.head()
