# %% [markdown]
# ### California house price prediction

# %% [markdown]
# kaggle 링크: <dr>
# https://www.kaggle.com/competitions/california-house-prices/overview

# %% [markdown]
# 1.Kaggle 인증

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\user\miniconda3\envs\ds\lib\site-packages (1.8.0)
# Requirement already satisfied: black>=24.10.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (26.1.0)
# Requirement already satisfied: bleach in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: mypy>=1.15.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: protobuf in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (6.33.4)
# Requirement already satisfied: python-slugify in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (80.9.0)
# Requirement already satisfied: six>=1.10 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (2.32.4.20260107)
# Requirement already satisfied: types-tqdm in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (1.1.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (25.0)
# Requirement already satisfied: pathspec>=1.0.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (1.0.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from black>=24.10.0->kaggle) (0.4.0)
# Requirement already satisfied: colorama in c:\users\user\miniconda3\envs\ds\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Requirement already satisfied: librt>=0.6.2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from mypy>=1.15.0->kaggle) (0.7.8)
# Requirement already satisfied: webencodings in c:\users\user\miniconda3\envs\ds\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniconda3\envs\ds\lib\site-packages (from requests->kaggle) (2026.1.4)

# %% [markdown]
# 2. 데이터 가져오기

# %%
# kaggle 패키지를 사용해 데이터를 다운로드 
# !kaggle competitions download -c california-house-prices
# Out:
# california-house-prices.zip: Skipping, found more recently modified local copy (use --force to force download)
